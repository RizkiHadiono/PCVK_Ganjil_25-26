# %% [markdown]
# <a href="https://colab.research.google.com/github/RizkiHadiono/PCVK_Ganjil_25-26/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://external-preview.redd.it/hJNL3HXwmJXzzIdyUKdsVQerrBIe0KbO7d26zEXWidE.jpg?auto=webp&s=4a8bf4911d40dddb64ebc30505e704003297f414"]


# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
    image = io.imread(url)                           #read image
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)  #resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)   #convert color to RGB
    final_frame = cv.hconcat((image, image_2))       #concatenate image
    cv2_imshow(final_frame)                          #show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=716x250>

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_tugas2_vertikal = image_rgb.copy()
image_tugas2_diagonal = image_rgb.copy()

#Membuat Garis Vertikal di tengah
for y in range(tinggi):
    image_tugas2_vertikal[y, int(lebar/2)] = [255, 255, 255]

#Membuat Garis Menyilang Diagonal
for x in range(lebar):
    #Diagonal 1 (Kiri atas ke kanan bawah)
    y1 = int(x * (tinggi / lebar))
    if y1 < tinggi:
        image_tugas2_diagonal[y1, x] = [255, 255, 255]

    #Diagonal 2 (Kanan atas ke kiri bawah)
    y2 = int((lebar - x) * (tinggi / lebar))
    if 0 <= y2 < tinggi:
        image_tugas2_diagonal[y2, x] = [255, 255, 255]

print("Hasil Tugas 2 (Garis Vertikal):")
cv2_imshow(cv.hconcat((image_rgb, image_tugas2_vertikal)))

print("\nHasil Tugas 2 (Garis Diagonal):")
cv2_imshow(cv.hconcat((image_rgb, image_tugas2_diagonal)))
# Out:
# Hasil Tugas 2 (Garis Vertikal):
# <PIL.Image.Image image mode=RGB size=716x250>
# Hasil Tugas 2 (Garis Diagonal):
# <PIL.Image.Image image mode=RGB size=716x250>

# %%
image_tugas3 = image_rgb.copy()

#Menentukan batas panjang garis
batas_kiri = int(lebar * 0.25)
batas_kanan = int(lebar * 0.75)

for x in range(batas_kiri, batas_kanan):
    image_tugas3[int(tinggi/2), x] = [255, 255, 255]

print("Hasil Tugas 3 (Garis Horizontal Sebagian):")
cv2_imshow(cv.hconcat((image_rgb, image_tugas3)))
# Out:
# Hasil Tugas 3 (Garis Horizontal Sebagian):
# <PIL.Image.Image image mode=RGB size=716x250>

# %%
image_tugas4 = image_rgb.copy()

#Menentukan batas koordinat kotak (contoh: di area kanan bawah)
y_awal = int(tinggi * 0.5)
y_akhir = int(tinggi * 0.8)
x_awal = int(lebar * 0.5)
x_akhir = int(lebar * 0.7)

for y in range(y_awal, y_akhir):
    for x in range(x_awal, x_akhir):
        image_tugas4[y, x] = [255, 255, 255]

print("Hasil Tugas 4 (Kotak Putih):")
cv2_imshow(cv.hconcat((image_rgb, image_tugas4)))
# Out:
# Hasil Tugas 4 (Kotak Putih):
# <PIL.Image.Image image mode=RGB size=716x250>

# %% [markdown]
# # Jawaban Pertanyaan Praktikum D2
#
# **1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?**
#
# Google Colab digunakan karena praktis, gratis, dan berbasis *cloud* (berjalan langsung di internet). Pengguna tidak perlu melakukan instalasi aplikasi di perangkat lokal, dan hasil eksekusi serta kodenya tersimpan secara otomatis.
#
# **2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?**
#
# Kegunaan setiap library:
# * `Numpy`: untuk komputasi angka/matriks.
# * `Pandas`: untuk mengolah data berbentuk tabel.
# * `cv2` (OpenCV) dan `skimage`: untuk keperluan pemrosesan gambar.
# * `matplotlib`: untuk membuat grafik.
# **Tidak semua library harus digunakan**; pada sesi ini `Pandas` dan `Matplotlib` hanya diimpor namun tidak dipakai dalam langkah praktikum pemrosesan gambar tersebut.
#
# **3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut: ![image.png](data:image/png;base64,...)
# Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?**
#
# Kode `cv.resize` berfungsi untuk mengubah (memperkecil) ukuran gambar menjadi setengah (50%) dari ukuran aslinya. Jika kode ini tidak dijalankan, gambar yang diproses dan ditampilkan akan tetap mempertahankan ukuran resolusi aslinya.
#
# ** 4. Perhatikan potongan kode progam berikut:
# ![image.png](data:image/png;base64,...)
#
# Apakah kegunaan kode `[255,255,255]`? Jelaskan! **
#
# Kode `[255, 255, 255]` merupakan representasi format warna RGB untuk **warna putih**. Dalam program tersebut, nilai ini diberikan pada titik-titik koordinat tertentu untuk mewarnai piksel sehingga membentuk sebuah garis horizontal berwarna putih.
#
# **5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!**
#
# Resolusi merupakan jumlah total piksel yang menyusun keseluruhan gambar. Semakin banyak jumlah pikselnya (resolusi tinggi), gambar akan tampak semakin detail dan tajam, sedangkan semakin sedikit pikselnya (resolusi rendah), gambar akan terlihat kurang jelas (pecah).
